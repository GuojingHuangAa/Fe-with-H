# %% [markdown]
# ### Hydrogen-surface reaction

# %% [markdown]
# <div style="text-align: center;">
#     <img src="attachment:7a9f761e-b38f-42bb-b4ee-c3a9d6b94582.png" alt="Screenshot" width="400"/>
# </div>
